# %% [markdown]
# <a href="https://colab.research.google.com/github/Fprietod/ALL_SIGNAL/blob/master/Manipulacion_datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from datetime import date

# %%
halo = pd.read_csv('/content/movies_new.csv')
halo_2 = pd.read_csv('/content/movies_old.csv')

# %%
today = date.today()
print("Today's date:", today)
# Out:
# Today's date: 2022-12-07

# %%
# Code
DataFrame.join(other, on=None, how='left', lsuffix='', rsuffix='', sort=False, validate=None)[source]

# %%
halo.head()
halo_2.head()
# Out:
#    ID_PELICULA                              TX_PELICULA CV_CLASIFICACION  \
# 0         3423                PERSIGUIENDO UN SUEÑO SUB                A
# 1         3502                PERSIGUIENDO UN SUEÑO DOB                A
# 2         5814  VICKY CRISTINA BARCELONA UN LIO AMOROSO              B15
# 3         5835          BOLT: UN PERRO FUERA DE  DIG 3D                A
# 4         5833        BOLT: UN PERRO FUERA DE SERIE DOB                A
#
#   FECHA_CREACION
# 0     2021-05-25
# 1     2021-05-25
# 2     2021-05-25
# 3     2021-05-25
# 4     2021-05-25

# %%
halo.tail()
# Out:
#      ID_PELICULA                TX_PELICULA CV_CLASIFICACION
# 130         5611                 LA DUQUESA              B15
# 131         5612          CHE  EL ARGENTINO                A
# 132         5851  PERSIGUIENDO UN SUEÑO DOB                A
# 133         5866            MARLEY Y YO SUB                A
# 134         5637       ORIGINALMENTE PIRATA                A

# %%
halo['FECHA_CREACION'] = today

# %%
halo.tail()
# Out:
#      ID_PELICULA                TX_PELICULA CV_CLASIFICACION FECHA_CREACION
# 130         5611                 LA DUQUESA              B15     2022-12-07
# 131         5612          CHE  EL ARGENTINO                A     2022-12-07
# 132         5851  PERSIGUIENDO UN SUEÑO DOB                A     2022-12-07
# 133         5866            MARLEY Y YO SUB                A     2022-12-07
# 134         5637       ORIGINALMENTE PIRATA                A     2022-12-07

# %%
ejemplo =halo.set_index('ID_PELICULA').join(halo_2.set_index('ID_PELICULA'),how='left',lsuffix='_t', rsuffix='_x')

# %%
ejemplo.drop('CV_CLASIFICACION_x', axis=1, inplace=True)

# %%
ejemplo.drop('TX_PELICULA_x', axis=1, inplace=True)

# %%
ejemplo.tail()
# Out:
#                                 TX_PELICULA_t CV_CLASIFICACION_t  \
# ID_PELICULA
# 36451          SIN SEÑAS PARTICULARES LED ESP                B15
# 36556                           LA VISITA ESP                B15
# 36580                       TERRITORIO SP ESP                B15
# 36629        SPACE JAM: UNA NUEVA ERA LED ESP                  A
# 36650                         LITTLE GIRL SUB                  A
#
#             FECHA_CREACION
# ID_PELICULA
# 36451                  NaN
# 36556                  NaN
# 36580                  NaN
# 36629                  NaN
# 36650                  NaN

# %%
ejemplo["FECHA_CREACION"].fillna(today, inplace = True)

# %%
ejemplo.to_csv("PUTOOOOS.csv")

# %%
halo.to_csv('Hola.csv')

# %%
halo['CV_CLASIFICACION'] = halo['CV_CLASIFICACION'].apply(lambda x : today if x == 'A' else 'Adios')
halo
# Out:
#      ID_PELICULA                       TX_PELICULA CV_CLASIFICACION
# 0          36580                 TERRITORIO SP ESP            Adios
# 1          36650                   LITTLE GIRL SUB       2022-12-07
# 2          36629  SPACE JAM: UNA NUEVA ERA LED ESP       2022-12-07
# 3          36556                     LA VISITA ESP            Adios
# 4          36450     SIN SEÑAS PARTICULARES SP ESP            Adios
# ..           ...                               ...              ...
# 130         5611                        LA DUQUESA            Adios
# 131         5612                 CHE  EL ARGENTINO       2022-12-07
# 132         5851         PERSIGUIENDO UN SUEÑO DOB       2022-12-07
# 133         5866                   MARLEY Y YO SUB       2022-12-07
# 134         5637              ORIGINALMENTE PIRATA       2022-12-07
#
# [135 rows x 3 columns]

# %%
ejemplo.head()
# Out:
#                                 TX_PELICULA_t CV_CLASIFICACION_t  \
# ID_PELICULA
# 3423                PERSIGUIENDO UN SUEÑO SUB                  A
# 3502                PERSIGUIENDO UN SUEÑO DOB                  A
# 3600         MORTAL KOMBAT 4DX/SCREENX/2D ESP                TBC
# 3858                    PERSIGUIENDO UN SUEÑO                  A
# 3873                     EL JUEGO DEL MIEDO 3                  C
#
#             FECHA_CREACION
# ID_PELICULA
# 3423            2021-05-25
# 3502            2021-05-25
# 3600            2021-05-25
# 3858            2021-05-25
# 3873            2021-05-25

# %%
ejemplo[ejemplo['FECHA_CREACION'].isna()]
# Out:
#                                                  TX_PELICULA_t  \
# ID_PELICULA
# 35698                                     TE LLEVO CONMIGO SUB
# 36053         DEMON SLAYER: MUGEN TRAIN LA PELÍCULA 4DX/2D SUB
# 36053        DEMON SLAYER: MUGEN TRAIN LA PELÍCULA P 4DX/2D...
# 36433                                       EL PLAN DIVINO ESP
# 36434                                        LA VERDAD LED SUB
# 36450                            SIN SEÑAS PARTICULARES SP ESP
# 36451                           SIN SEÑAS PARTICULARES LED ESP
# 36556                                            LA VISITA ESP
# 36580                                        TERRITORIO SP ESP
# 36629                         SPACE JAM: UNA NUEVA ERA LED ESP
# 36650                                          LITTLE GIRL SUB
#
#             CV_CLASIFICACION_t FECHA_CREACION
# ID_PELICULA
# 35698                        B            NaN
# 36053                        B            NaN
# ...

# %%
halo['FECHA_CREACION'] = today

# %%
halo
# Out:
#      ID_PELICULA                       TX_PELICULA CV_CLASIFICACION  \
# 0          36580                 TERRITORIO SP ESP              B15
# 1          36650                   LITTLE GIRL SUB                A
# 2          36629  SPACE JAM: UNA NUEVA ERA LED ESP                A
# 3          36556                     LA VISITA ESP              B15
# 4          36450     SIN SEÑAS PARTICULARES SP ESP              B15
# ..           ...                               ...              ...
# 130         5611                        LA DUQUESA              B15
# 131         5612                 CHE  EL ARGENTINO                A
# 132         5851         PERSIGUIENDO UN SUEÑO DOB                A
# 133         5866                   MARLEY Y YO SUB                A
# 134         5637              ORIGINALMENTE PIRATA                A
#
#     FECHA_CREACION
# 0       2022-12-07
# 1       2022-12-07
# 2       2022-12-07
# 3       2022-12-07
# 4       2022-12-07
# ..             ...
# ...

# %%
ejemplo
# Out:
#                                 TX_PELICULA_t CV_CLASIFICACION_t  \
# ID_PELICULA
# 3423                PERSIGUIENDO UN SUEÑO SUB                  A
# 3502                PERSIGUIENDO UN SUEÑO DOB                  A
# 3600         MORTAL KOMBAT 4DX/SCREENX/2D ESP                TBC
# 3858                    PERSIGUIENDO UN SUEÑO                  A
# 3873                     EL JUEGO DEL MIEDO 3                  C
# ...                                       ...                ...
# 36451          SIN SEÑAS PARTICULARES LED ESP                B15
# 36556                           LA VISITA ESP                B15
# 36580                       TERRITORIO SP ESP                B15
# 36629        SPACE JAM: UNA NUEVA ERA LED ESP                  A
# 36650                         LITTLE GIRL SUB                  A
#
#             FECHA_CREACION
# ID_PELICULA
# 3423            2022-12-07
# 3502            2022-12-07
# 3600            2022-12-07
# 3858            2022-12-07
# ...

# %%
ejemplo['FECHA_CREACION'] =='NaN'
# Out:
# ID_PELICULA
# 3423     False
# 3502     False
# 3600     False
# 3858     False
# 3873     False
#          ...
# 36451    False
# 36556    False
# 36580    False
# 36629    False
# 36650    False
# Name: FECHA_CREACION, Length: 137, dtype: bool

# %%
ejemplo.tail()
# Out:
#                                 TX_PELICULA_t CV_CLASIFICACION_t  \
# ID_PELICULA
# 36451          SIN SEÑAS PARTICULARES LED ESP                B15
# 36556                           LA VISITA ESP                B15
# 36580                       TERRITORIO SP ESP                B15
# 36629        SPACE JAM: UNA NUEVA ERA LED ESP                  A
# 36650                         LITTLE GIRL SUB                  A
#
#             FECHA_CREACION
# ID_PELICULA
# 36451                  NaN
# 36556                  NaN
# 36580                  NaN
# 36629                  NaN
# 36650                  NaN

# %%
ejemplo.to_csv('PUTOS_TODOS.csv')
